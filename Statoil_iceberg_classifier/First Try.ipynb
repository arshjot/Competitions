# %% [markdown]
# #### Import packages

# %%
# import torch.multiprocessing as mp
# mp.set_start_method('spawn') 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import shutil
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
import random
import cv2

import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from tensorboardX import SummaryWriter
import torch.utils.data
import torch.utils.data as data_utils

seed = 0
# random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
np.random.seed(seed)
# from utils_3 import *
# from utils import *
from utils_diff_ch import *

# %% [markdown]
# #### Load and Prepare Data

# %%
data = pd.read_json('./Data/train.json')
test = pd.read_json('./Data/test.json')

# %%
data['band_1'] = data['band_1'].apply(lambda x : np.array(x).reshape(75, 75))
data['band_2'] = data['band_2'].apply(lambda x : np.array(x).reshape(75, 75))

test['band_1'] = test['band_1'].apply(lambda x : np.array(x).reshape(75, 75))
test['band_2'] = test['band_2'].apply(lambda x : np.array(x).reshape(75, 75))

data['inc_angle'] = pd.to_numeric(data['inc_angle'], errors='coerce').fillna(0.0)
test['inc_angle'] = pd.to_numeric(test['inc_angle'], errors='coerce')

train, val = train_test_split(data, test_size=0.2, random_state=42)

# %%
def scale_range (input_, min_, max_):
    input_ += -(np.min(input_))
    input_ /= np.max(input_) / (max_ - min_)
    input_ += min_
    return input_

# %%
band_1_tr = np.concatenate([im for im in train['band_1']]).reshape(-1, 75, 75)
band_2_tr = np.concatenate([im for im in train['band_2']]).reshape(-1, 75, 75)
X_train = np.stack((band_1_tr, band_2_tr), axis=1)
X_train = [X_train, np.array(train['inc_angle']).reshape((len(train), 1))]

band_1_val = np.concatenate([im for im in val['band_1']]).reshape(-1, 75, 75)
band_2_val = np.concatenate([im for im in val['band_2']]).reshape(-1, 75, 75)
X_val = np.stack((band_1_val, band_2_val), axis=1)
X_val = [X_val, np.array(val['inc_angle']).reshape((len(val), 1))]

band_1_test = np.concatenate([im for im in test['band_1']]).reshape(-1, 75, 75)
band_2_test = np.concatenate([im for im in test['band_2']]).reshape(-1, 75, 75)
# band_3_test = scale_range(band_1_test/band_2_test, -1, 1)
rgb = np.stack((band_1_test, band_2_test), axis=1)
X_test = [rgb, np.array(test['inc_angle']).reshape((len(test), 1))]

y_train = train['is_iceberg'].values.astype(np.float32)
y_val = val['is_iceberg'].values.astype(np.float32)

# %% [markdown]
# #### PyTorch Model

# %%
# Hyper Parameters
width = 75
height = 75
channels = 2
padding = 0

# %%
# Data Loader (Input Pipeline)
class icebergDataset(data_utils.Dataset):
    """Iceberg-Ship dataset."""

    def __init__(self, X, y=None, transform=None):
        self.X_images = X[0]
        self.X_angles = torch.from_numpy(X[1]).float()
        if y!=None:
            self.y = torch.from_numpy(y).long()
        else:
            self.y=None
        self.transform = transform

    def __len__(self):
        return len(self.X_images)

    def __getitem__(self, idx):
        im = self.X_images[idx]
        if self.transform:
#             if np.random.random() < 0.2:
#                 im = cv2.blur(im, (2,2))
            im = randomErodeDilate(im, u=0.2)
            im = randomZoomOut(im, u=0.5)
            im = randomNoisy(im, u=0.4)
            im = randomShift(im, u=0.3)
        
        try:
            if self.y==None:
                return [torch.from_numpy(im).float(), self.X_angles[idx]]
        except:
            pass
            
        return [torch.from_numpy(im).float(), self.X_angles[idx], self.y[idx]]

# %%
def save_checkpoint(state, is_best, filename='./Models/checkpoint.pth.tar'):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, './Models/model_best.pth.tar')

# %%
train_dataset = icebergDataset(X_train, y_train, transform=True)
val_dataset = icebergDataset(X_val, y_val)
test_dataset = icebergDataset(X_test)
# Out:
# /home/arsh/anaconda3/envs/torch/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.

# %%
act = nn.ReLU()
class net(nn.Module):
    def __init__(self):
        super(net, self).__init__()
        self.batch = nn.BatchNorm2d(channels)
        self.batch1D = nn.BatchNorm1d(1)
        self.layer1 = nn.Sequential(
            nn.Conv2d(channels, 9, kernel_size=3, padding=padding),
            nn.BatchNorm2d(9),
            act,
            nn.Conv2d(9, 18, kernel_size=3, padding=padding),
            nn.BatchNorm2d(18),
            act,
            nn.MaxPool2d(2),
            nn.Dropout(0.2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(18, 24, kernel_size=3, padding=padding),
            nn.BatchNorm2d(24),
            act,
            nn.Conv2d(24, 36, kernel_size=3, padding=padding),
            nn.BatchNorm2d(36),
            act,
            nn.MaxPool2d(2),
            nn.Dropout(0.2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(36, 72, kernel_size=2, padding=padding),
            nn.BatchNorm2d(72),
            act,
            nn.MaxPool2d(2),
            nn.Dropout(0.2))
        self.layer4 = nn.Sequential(
            nn.Conv2d(72, 144, kernel_size=2, padding=padding),
            nn.BatchNorm2d(144),
            act,
            nn.MaxPool2d(2),
            nn.Dropout(0.2))
        self.layer_shallow = nn.Sequential(
            nn.Conv2d(channels, 128, kernel_size=3, padding=padding),
            nn.BatchNorm2d(128),
            act,
            nn.MaxPool2d(2),
            nn.Dropout(0.2))
        self.fc1 = nn.Sequential(
            nn.Linear(1+(3*3*144), 512),
            act,
            nn.Dropout(0.5))
        self.fc2 = nn.Sequential(
            nn.Linear(512, 196),
            act,
            nn.Dropout(0.5))
        self.fc3 = nn.Linear(196, 2)
        self.sig = nn.Sigmoid()
        
        
    def forward(self, x_im, x_angle):
        x_im = self.batch(x_im)
        x_angle = self.batch1D(x_angle)
        out = self.layer1(x_im)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = out.view(out.size(0), -1)
#         out_shallow = self.layer_shallow(x_im)
#         out_shallow  = F.max_pool2d(out_shallow, kernel_size=out_shallow.size()[2:])
#         out_shallow = out_shallow.view(out_shallow.size(0), -1)
        out = torch.cat([out, x_angle], dim=1)
        out = self.fc1(out)
        out = self.fc2(out)
        out = self.fc3(out)
        return out

# %%
# k = 12
# padding = 1
# act = nn.LeakyReLU()
# class net(nn.Module):
#     def __init__(self):
#         super(net, self).__init__()
#         self.batch = nn.BatchNorm2d(channels)
#         self.batch1D = nn.BatchNorm1d(1)
#         self.init = nn.Sequential(
#             nn.Conv2d(channels, k*2, kernel_size=3, padding=padding),
#             nn.BatchNorm2d(k*2),
#             act,
#             nn.Dropout(0))
#         self.b1l1 = nn.Sequential(
#             nn.Conv2d(k*2, k, kernel_size=3, padding=padding),
#             nn.BatchNorm2d(k),
#             act,
#             nn.Dropout(0))
#         self.b1l2 = nn.Sequential(
#             nn.Conv2d(k*3, k, kernel_size=3, padding=padding),
#             nn.BatchNorm2d(k),
#             act,
#             nn.Dropout(0))
#         self.transition1 = nn.Sequential(
#             nn.Conv2d(k*4, k*4, kernel_size=1, padding=0),
#             nn.BatchNorm2d(k*4),
#             act,
#             nn.MaxPool2d(2),
#             nn.Dropout(0))
#         self.b2l1 = nn.Sequential(
#             nn.Conv2d(k*4, k, kernel_size=2, padding=0),
#             nn.BatchNorm2d(k),
#             act,
#             nn.Dropout(0))
#         self.b2l2 = nn.Sequential(
#             nn.Conv2d(k*5, k, kernel_size=2, padding=0),
#             nn.BatchNorm2d(k),
#             act,
#             nn.Dropout(0))
#         self.transition2 = nn.Sequential(
#             nn.Conv2d(k*6, k*6, kernel_size=1, padding=0),
#             nn.BatchNorm2d(k*6),
#             act,
#             nn.MaxPool2d(2),
#             nn.Dropout(0))
#         self.b3l1 = nn.Sequential(
#             nn.Conv2d(k*6, k, kernel_size=2, padding=0),
#             nn.BatchNorm2d(k),
#             act,
#             nn.Dropout(0))
#         self.b3l2 = nn.Sequential(
#             nn.Conv2d(k*7, k, kernel_size=2, padding=0),
#             nn.BatchNorm2d(k),
#             act,
#             nn.Dropout(0))
#         self.transition3 = nn.Sequential(
#             nn.Conv2d(k*8, k*8, kernel_size=1, padding=0),
#             nn.BatchNorm2d(k*8),
#             act,
#             nn.MaxPool2d(2),
#             nn.Dropout(0))
#         self.layer3 = nn.Sequential(
#             nn.Conv2d(k*8, k*6, kernel_size=2, padding=0),
#             nn.BatchNorm2d(k*6),
#             act,
#             nn.MaxPool2d(2),
#             nn.Dropout(0))
#         self.layer4 = nn.Sequential(
#             nn.Conv2d(k*6, k*4, kernel_size=2, padding=0),
#             nn.BatchNorm2d(k*4),
#             act,
#             nn.MaxPool2d(2),
#             nn.Dropout(0))
#         self.fc1 = nn.Sequential(
#             nn.Linear(1+(4*4*k*6), 512),
#             act,
#             nn.Dropout(0.5))
#         self.fc2 = nn.Sequential(
#             nn.Linear(512, 196),
#             act,
#             nn.Dropout(0.3))
#         self.fc3 = nn.Linear(196, 2)
#         self.sig = nn.Sigmoid()
        
        
#     def forward(self, x_im, x_angle):
#         x_im = self.batch(x_im)
#         x_angle = self.batch1D(x_angle)
#         out_prev = self.init(x_im)
#         out = self.b1l1(out_prev)
#         out_prev = torch.cat([out, out_prev], dim=1)
#         out = self.b1l2(out_prev)
#         out_prev = torch.cat([out, out_prev], dim=1)
#         out_prev = self.transition1(out_prev)
#         out = self.b2l1(out_prev)
#         out_prev = torch.cat([F.pad(out, (0,1,0,1), "constant", 0), out_prev], dim=1)
#         out = self.b2l2(out_prev)
#         out_prev = torch.cat([F.pad(out, (0,1,0,1), "constant", 0), out_prev], dim=1)
#         out_prev = self.transition2(out_prev)
#         out = self.b3l1(out_prev)
#         out_prev = torch.cat([F.pad(out, (0,1,0,1), "constant", 0), out_prev], dim=1)
#         out = self.b3l2(out_prev)
#         out_prev = torch.cat([F.pad(out, (0,1,0,1), "constant", 0), out_prev], dim=1)
#         out_prev = self.transition3(out_prev)
#         out = self.layer3(out_prev)
# #         out = self.layer4(out)
#         out = out.view(out.size(0), -1)
# #         out_shallow = self.layer_shallow(x_im)
# #         out_shallow  = F.max_pool2d(out_shallow, kernel_size=out_shallow.size()[2:])
# #         out_shallow = out_shallow.view(out_shallow.size(0), -1)
#         out = torch.cat([out, x_angle], dim=1)
#         out = self.fc1(out)
#         out = self.fc2(out)
#         out = self.fc3(out)
#         return out

# %%
def weight_init(m): 
    if isinstance(m, nn.Conv2d):
        torch.nn.init.xavier_uniform(m.weight.data)
    if isinstance(m, nn.Linear):
        torch.nn.init.orthogonal(m.weight.data)

# %%
writer = SummaryWriter()
iceNet = net()
iceNet.apply(weight_init).cuda()
# Out:
# net (
#   (batch): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True)
#   (batch1D): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True)
#   (layer1): Sequential (
#     (0): Conv2d(2, 9, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True)
#     (2): LeakyReLU (0.01)
#     (3): Conv2d(9, 18, kernel_size=(3, 3), stride=(1, 1))
#     (4): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True)
#     (5): LeakyReLU (0.01)
#     (6): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (7): Dropout (p = 0.2)
#   )
#   (layer2): Sequential (
#     (0): Conv2d(18, 24, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True)
#     (2): LeakyReLU (0.01)
#     (3): Conv2d(24, 36, kernel_size=(3, 3), stride=(1, 1))
#     (4): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True)
#     (5): LeakyReLU (0.01)
#     (6): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (7): Dropout (p = 0.2)
#   )
#   (layer3): Sequential (
#     (0): Conv2d(36, 72, kernel_size=(2, 2), stride=(1, 1))
#     (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True)
#     (2): LeakyReLU (0.01)
#     (3): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (4): Dropout (p = 0.2)
#   )
#   (layer4): Sequential (
#     (0): Conv2d(72, 144, kernel_size=(2, 2), stride=(1, 1))
#     (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True)
#     (2): LeakyReLU (0.01)
#     (3): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (4): Dropout (p = 0.2)
#   )
#   (layer_shallow): Sequential (
#     (0): Conv2d(2, 128, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (2): LeakyReLU (0.01)
#     (3): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (4): Dropout (p = 0.2)
#   )
#   (fc1): Sequential (
#     (0): Linear (1297 -> 512)
#     (1): LeakyReLU (0.01)
#     (2): Dropout (p = 0.5)
#   )
#   (fc2): Sequential (
#     (0): Linear (512 -> 196)
#     (1): LeakyReLU (0.01)
#     (2): Dropout (p = 0.5)
#   )
#   (fc3): Linear (196 -> 2)
#   (sig): Sigmoid ()
# )

# %%
num_epochs = 200
batch_size = 32
learning_rate = 0.001

# %%
# Loss and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(iceNet.parameters(), lr=learning_rate, weight_decay=0.0001)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

def accuracy(loader):
    iceNet.eval()
    correct = 0
    total = 0
    loss = []
    for features, features_angle, labels in loader:
        features = features.cuda()
        labels = labels.cuda()
        features_angle = features_angle.cuda()
        features = Variable(features, volatile=True)
        features_angle = Variable(features_angle, volatile=True)
        labels = Variable(labels, volatile=True)
        outputs = iceNet(features, features_angle)
        _loss = criterion(outputs, labels)
        loss.append(_loss)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.data).sum()
        
    return np.mean(loss).data[0], (100 * correct / total)

# %%
# Train the Model
best_prec1 = 1
for epoch in range(num_epochs):
    epoch_train_loss = []
    for i, (features, features_angle, labels) in enumerate(train_loader):
        iceNet.train()
        features = features.cuda()
        labels = labels.cuda()
        features = Variable(features).float()
        features_angle = Variable(features_angle).cuda()
        labels = Variable(labels).long()
        # Forward + Backward + Optimize
        optimizer.zero_grad()
        outputs = iceNet(features, features_angle)
        writer.add_graph(iceNet, outputs)
#         writer.add_histogram('hist_fc1', iceNet.fc1[0].weight.data.cpu().numpy(), i)
#         writer.add_histogram('hist_fc2', iceNet.fc2[0].weight.data.cpu().numpy(), i)
#         writer.add_histogram('hist_fc3', iceNet.fc3.weight.data.cpu().numpy(), i)
        loss = criterion(outputs, labels)
        epoch_train_loss.append(loss)
        loss.backward()
        optimizer.step()
        
    prec1 = accuracy(val_loader)[0]
    print ('Epoch [%d/%d] \nTraining Loss: %.4f' % (epoch+1, num_epochs, np.mean(epoch_train_loss).data[0]))
    print('Validation Loss: %.4f, Accuracy: %.2f%%' % accuracy(val_loader))
    
    is_best = prec1 < best_prec1
    best_prec1 = min(prec1, best_prec1)
#     save_checkpoint({
#         'epoch': epoch + 1,
#         'state_dict': iceNet.state_dict(),
#         'best_prec1': best_prec1,
#         'optimizer' : optimizer.state_dict(),
#     }, is_best)

print(best_prec1)
# export scalar data to JSON for external processing
writer.close()
# Out:
# Epoch [1/200]
# Training Loss: 0.6808
# Validation Loss: 0.6635, Accuracy: 65.42%
# Epoch [2/200]
# Training Loss: 0.5974
# Validation Loss: 0.6173, Accuracy: 68.54%
# Epoch [3/200]
# Training Loss: 0.5416
# Validation Loss: 0.4194, Accuracy: 77.57%
# Epoch [4/200]
# Training Loss: 0.5073
# Validation Loss: 0.4121, Accuracy: 79.44%
# Epoch [5/200]
# Training Loss: 0.4798
# Validation Loss: 0.3716, Accuracy: 83.80%
# Epoch [6/200]
# Training Loss: 0.4322
# Validation Loss: 0.3623, Accuracy: 83.49%
# Epoch [7/200]
# Training Loss: 0.4099
# Validation Loss: 0.3144, Accuracy: 84.42%
# Epoch [8/200]
# Training Loss: 0.4066
# Validation Loss: 0.3336, Accuracy: 87.23%
# Epoch [9/200]
# Training Loss: 0.3785
# Validation Loss: 0.3064, Accuracy: 86.60%
# Epoch [10/200]
# Training Loss: 0.3592
# Validation Loss: 0.3176, Accuracy: 83.18%
# Epoch [11/200]
# Training Loss: 0.3926
# Validation Loss: 0.3051, Accuracy: 85.05%
# Epoch [12/200]
# Training Loss: 0.4080
# Validation Loss: 0.2789, Accuracy: 86.60%
# Epoch [13/200]
# Training Loss: 0.3556
# Validation Loss: 0.2697, Accuracy: 87.54%
# Epoch [14/200]
# Training Loss: 0.3829
# Validation Loss: 0.2498, Accuracy: 87.85%
# Epoch [15/200]
# Training Loss: 0.3414
# Validation Loss: 0.2484, Accuracy: 89.72%
# Epoch [16/200]
# Training Loss: 0.3353
# Validation Loss: 0.2394, Accuracy: 89.10%
# Epoch [17/200]
# Training Loss: 0.3185
# Validation Loss: 0.2229, Accuracy: 88.47%
# Epoch [18/200]
# Training Loss: 0.3445
# Validation Loss: 0.2346, Accuracy: 88.16%
# Epoch [19/200]
# Training Loss: 0.3132
# Validation Loss: 0.2224, Accuracy: 89.41%
# Epoch [20/200]
# Training Loss: 0.3012
# Validation Loss: 0.2326, Accuracy: 89.72%
# Epoch [21/200]
# Training Loss: 0.3320
# Validation Loss: 0.2669, Accuracy: 88.79%
# Epoch [22/200]
# Training Loss: 0.3174
# Validation Loss: 0.2209, Accuracy: 88.47%
# Epoch [23/200]
# Training Loss: 0.3158
# Validation Loss: 0.2102, Accuracy: 90.34%
# Epoch [24/200]
# Training Loss: 0.3030
# Validation Loss: 0.2131, Accuracy: 89.10%
# Epoch [25/200]
# Training Loss: 0.2925
# Validation Loss: 0.2164, Accuracy: 89.41%
# Epoch [26/200]
# Training Loss: 0.3026
# Validation Loss: 0.2150, Accuracy: 90.65%
# Epoch [27/200]
# Training Loss: 0.3904
# Validation Loss: 0.2226, Accuracy: 89.10%
# Epoch [28/200]
# Training Loss: 0.2906
# Validation Loss: 0.2078, Accuracy: 90.03%
# Epoch [29/200]
# Training Loss: 0.2811
# Validation Loss: 0.2927, Accuracy: 88.16%
# Epoch [30/200]
# Training Loss: 0.2998
# Validation Loss: 0.2226, Accuracy: 90.34%
# Epoch [31/200]
# Training Loss: 0.2769
# Validation Loss: 0.2280, Accuracy: 88.79%
# Epoch [32/200]
# Training Loss: 0.2734
# Validation Loss: 0.2224, Accuracy: 89.72%
# Epoch [33/200]
# Training Loss: 0.2645
# Validation Loss: 0.1967, Accuracy: 90.65%
# Epoch [34/200]
# Training Loss: 0.2475
# Validation Loss: 0.2158, Accuracy: 90.03%
# Epoch [35/200]
# Training Loss: 0.2878
# Validation Loss: 0.1939, Accuracy: 90.34%
# Epoch [36/200]
# Training Loss: 0.3364
# Validation Loss: 0.2045, Accuracy: 89.41%
# Epoch [37/200]
# Training Loss: 0.2930
# Validation Loss: 0.2222, Accuracy: 89.10%
# Epoch [38/200]
# Training Loss: 0.3376
# Validation Loss: 0.1907, Accuracy: 91.28%
# Epoch [39/200]
# Training Loss: 0.3179
# Validation Loss: 0.2189, Accuracy: 90.65%
# Epoch [40/200]
# Training Loss: 0.2622
# Validation Loss: 0.1939, Accuracy: 92.21%
# Epoch [41/200]
# Training Loss: 0.2675
# Validation Loss: 0.2110, Accuracy: 89.72%
# Epoch [42/200]
# Training Loss: 0.2773
# Validation Loss: 0.2035, Accuracy: 91.28%
# Epoch [43/200]
# Training Loss: 0.2654
# Validation Loss: 0.2031, Accuracy: 90.97%
# Epoch [44/200]
# Training Loss: 0.2590
# Validation Loss: 0.1969, Accuracy: 91.28%
# Epoch [45/200]
# Training Loss: 0.2585
# Validation Loss: 0.1923, Accuracy: 91.28%
# Epoch [46/200]
# Training Loss: 0.2766
# Validation Loss: 0.2065, Accuracy: 91.28%
# Epoch [47/200]
# Training Loss: 0.2836
# Validation Loss: 0.2028, Accuracy: 90.97%
# Epoch [48/200]
# Training Loss: 0.2694
# Validation Loss: 0.1808, Accuracy: 92.21%
# Epoch [49/200]
# Training Loss: 0.2520
# Validation Loss: 0.2067, Accuracy: 90.65%
# Epoch [50/200]
# Training Loss: 0.3392
# Validation Loss: 0.2151, Accuracy: 89.72%
# Epoch [51/200]
# Training Loss: 0.3264
# Validation Loss: 0.1944, Accuracy: 89.72%
# Epoch [52/200]
# Training Loss: 0.2987
# Validation Loss: 0.2028, Accuracy: 91.59%
# Epoch [53/200]
# Training Loss: 0.2873
# Validation Loss: 0.1893, Accuracy: 91.28%
# Epoch [54/200]
# Training Loss: 0.2562
# Validation Loss: 0.1918, Accuracy: 89.72%
# Epoch [55/200]
# Training Loss: 0.2264
# Validation Loss: 0.2058, Accuracy: 90.97%
# Epoch [56/200]
# Training Loss: 0.2507
# Validation Loss: 0.1938, Accuracy: 91.28%
# Epoch [57/200]
# Training Loss: 0.2696
# Validation Loss: 0.2426, Accuracy: 89.10%
# Epoch [58/200]
# Training Loss: 0.3556
# Validation Loss: 0.1850, Accuracy: 91.59%
# Epoch [59/200]
# Training Loss: 0.2846
# Validation Loss: 0.1939, Accuracy: 90.34%
# Epoch [60/200]
# Training Loss: 0.2733
# Validation Loss: 0.1875, Accuracy: 90.34%
# Epoch [61/200]
# Training Loss: 0.2628
# Validation Loss: 0.1812, Accuracy: 91.59%
# Epoch [62/200]
# Training Loss: 0.2762
# Validation Loss: 0.1789, Accuracy: 91.90%
# Epoch [63/200]
# Training Loss: 0.2507
# Validation Loss: 0.1829, Accuracy: 91.59%
# Epoch [64/200]
# Training Loss: 0.2692
# Validation Loss: 0.1976, Accuracy: 90.34%
# Epoch [65/200]
# Training Loss: 0.3772
# Validation Loss: 0.1894, Accuracy: 91.28%
# Epoch [66/200]
# Training Loss: 0.4230
# Validation Loss: 0.2090, Accuracy: 91.28%
# Epoch [67/200]
# Training Loss: 0.3423
# Validation Loss: 0.1971, Accuracy: 90.34%
# Epoch [68/200]
# Training Loss: 0.2944
# Validation Loss: 0.1963, Accuracy: 90.65%
# Epoch [69/200]
# Training Loss: 0.2672
# Validation Loss: 0.1941, Accuracy: 91.59%
# Epoch [70/200]
# Training Loss: 0.2649
# Validation Loss: 0.2068, Accuracy: 89.72%
# Epoch [71/200]
# Training Loss: 0.2332
# Validation Loss: 0.1900, Accuracy: 91.28%
# Epoch [72/200]
# Training Loss: 0.2459
# Validation Loss: 0.1904, Accuracy: 90.65%
# Epoch [73/200]
# Training Loss: 0.2668
# Validation Loss: 0.1886, Accuracy: 90.65%
# Epoch [74/200]
# Training Loss: 0.2532
# Validation Loss: 0.1910, Accuracy: 90.65%
# Epoch [75/200]
# Training Loss: 0.2268
# Validation Loss: 0.2075, Accuracy: 92.83%
# Epoch [76/200]
# Training Loss: 0.2545
# Validation Loss: 0.1837, Accuracy: 91.90%
# Epoch [77/200]
# Training Loss: 0.2651
# Validation Loss: 0.1966, Accuracy: 91.28%
# Epoch [78/200]
# Training Loss: 0.2383
# Validation Loss: 0.2023, Accuracy: 90.97%
# Epoch [79/200]
# Training Loss: 0.2565
# Validation Loss: 0.1996, Accuracy: 90.34%
# Epoch [80/200]
# Training Loss: 0.2409
# Validation Loss: 0.1787, Accuracy: 91.90%
# Epoch [81/200]
# Training Loss: 0.2270
# Validation Loss: 0.1967, Accuracy: 90.97%
# Epoch [82/200]
# Training Loss: 0.2216
# Validation Loss: 0.2001, Accuracy: 91.28%
# Epoch [83/200]
# Training Loss: 0.2233
# Validation Loss: 0.1944, Accuracy: 90.34%
# Epoch [84/200]
# Training Loss: 0.2389
# Validation Loss: 0.1846, Accuracy: 90.97%
# Epoch [85/200]
# Training Loss: 0.2189
# Validation Loss: 0.2189, Accuracy: 91.28%
# Epoch [86/200]
# Training Loss: 0.2614
# Validation Loss: 0.1848, Accuracy: 90.97%
# Epoch [87/200]
# Training Loss: 0.2854
# Validation Loss: 0.1892, Accuracy: 92.52%
# Epoch [88/200]
# Training Loss: 0.3031
# Validation Loss: 0.2026, Accuracy: 90.65%
# Epoch [89/200]
# Training Loss: 0.2408
# Validation Loss: 0.1974, Accuracy: 90.97%
# Epoch [90/200]
# Training Loss: 0.2670
# Validation Loss: 0.1751, Accuracy: 91.59%
# Epoch [91/200]
# Training Loss: 0.2490
# Validation Loss: 0.1883, Accuracy: 90.65%
# Epoch [92/200]
# Training Loss: 0.2247
# Validation Loss: 0.2160, Accuracy: 90.97%
# Epoch [93/200]
# Training Loss: 0.2471
# Validation Loss: 0.1960, Accuracy: 91.28%
# Epoch [94/200]
# Training Loss: 0.2819
# Validation Loss: 0.1799, Accuracy: 91.59%
# Epoch [95/200]
# Training Loss: 0.3126
# Validation Loss: 0.1908, Accuracy: 91.28%
# Epoch [96/200]
# Training Loss: 0.3165
# Validation Loss: 0.2125, Accuracy: 90.34%
# Epoch [97/200]
# Training Loss: 0.2616
# Validation Loss: 0.1822, Accuracy: 91.59%
# Epoch [98/200]
# Training Loss: 0.2766
# Validation Loss: 0.1832, Accuracy: 91.59%
# Epoch [99/200]
# Training Loss: 0.2160
# Validation Loss: 0.1882, Accuracy: 91.90%
# Epoch [100/200]
# Training Loss: 0.1979
# Validation Loss: 0.1939, Accuracy: 91.28%
# Epoch [101/200]
# Training Loss: 0.2346
# Validation Loss: 0.1899, Accuracy: 90.97%
# Epoch [102/200]
# Training Loss: 0.2322
# Validation Loss: 0.2109, Accuracy: 91.28%
# Epoch [103/200]
# Training Loss: 0.2487
# Validation Loss: 0.1870, Accuracy: 90.97%
# Epoch [104/200]
# Training Loss: 0.2341
# Validation Loss: 0.2031, Accuracy: 91.59%
# Epoch [105/200]
# Training Loss: 0.2268
# Validation Loss: 0.1870, Accuracy: 91.59%
# Epoch [106/200]
# Training Loss: 0.2163
# Validation Loss: 0.1908, Accuracy: 90.97%
# Epoch [107/200]
# Training Loss: 0.2059
# Validation Loss: 0.2040, Accuracy: 91.28%
# Epoch [108/200]
# Training Loss: 0.2387
# Validation Loss: 0.1993, Accuracy: 91.59%
# Epoch [109/200]
# Training Loss: 0.2581
# Validation Loss: 0.1892, Accuracy: 90.97%
# Epoch [110/200]
# Training Loss: 0.2577
# Validation Loss: 0.1877, Accuracy: 91.59%
# Epoch [111/200]
# Training Loss: 0.2897
# Validation Loss: 0.2553, Accuracy: 89.10%
# Epoch [112/200]
# Training Loss: 0.3250
# Validation Loss: 0.1917, Accuracy: 90.97%
# Epoch [113/200]
# Training Loss: 0.2660
# Validation Loss: 0.1831, Accuracy: 91.90%
# Epoch [114/200]
# Training Loss: 0.2171
# Validation Loss: 0.2005, Accuracy: 92.52%
# Epoch [115/200]
# Training Loss: 0.2538
# Validation Loss: 0.1812, Accuracy: 90.65%
# Epoch [116/200]
# Training Loss: 0.2395
# Validation Loss: 0.1998, Accuracy: 91.59%
# Epoch [117/200]
# Training Loss: 0.2682
# Validation Loss: 0.1974, Accuracy: 90.65%
# Epoch [118/200]
# Training Loss: 0.2275
# Validation Loss: 0.2064, Accuracy: 90.34%
# Epoch [119/200]
# Training Loss: 0.2881
# Validation Loss: 0.2039, Accuracy: 91.59%
# Epoch [120/200]
# Training Loss: 0.2290
# Validation Loss: 0.2178, Accuracy: 90.03%
# Epoch [121/200]
# Training Loss: 0.2308
# Validation Loss: 0.2078, Accuracy: 90.34%
# Epoch [122/200]
# Training Loss: 0.2258
# Validation Loss: 0.1888, Accuracy: 91.28%
# Epoch [123/200]
# Training Loss: 0.2338
# Validation Loss: 0.2021, Accuracy: 91.28%
# Epoch [124/200]
# Training Loss: 0.2144
# Validation Loss: 0.2037, Accuracy: 91.59%
# Epoch [125/200]
# Training Loss: 0.2195
# Validation Loss: 0.1897, Accuracy: 91.59%
# Epoch [126/200]
# Training Loss: 0.2083
# Validation Loss: 0.1934, Accuracy: 91.28%
# Epoch [127/200]
# Training Loss: 0.1942
# Validation Loss: 0.2019, Accuracy: 92.52%
# Epoch [128/200]
# Training Loss: 0.2246
# Validation Loss: 0.1833, Accuracy: 91.90%
# Epoch [129/200]
# Training Loss: 0.2123
# Validation Loss: 0.1981, Accuracy: 92.83%
# Epoch [130/200]
# Training Loss: 0.2487
# Validation Loss: 0.1946, Accuracy: 91.28%
# Epoch [131/200]
# Training Loss: 0.2126
# Validation Loss: 0.1988, Accuracy: 92.52%
# Epoch [132/200]
# Training Loss: 0.2459
# Validation Loss: 0.1824, Accuracy: 91.59%
# Epoch [133/200]
# Training Loss: 0.2551
# Validation Loss: 0.1869, Accuracy: 91.90%
# Epoch [134/200]
# Training Loss: 0.2369
# Validation Loss: 0.2030, Accuracy: 91.59%
# Epoch [135/200]
# Training Loss: 0.2256
# Validation Loss: 0.1955, Accuracy: 91.59%
# Epoch [136/200]
# Training Loss: 0.2291
# Validation Loss: 0.2117, Accuracy: 91.28%
# Epoch [137/200]
# Training Loss: 0.2943
# Validation Loss: 0.1900, Accuracy: 91.28%
# Epoch [138/200]
# Training Loss: 0.2260
# Validation Loss: 0.2111, Accuracy: 91.28%
# Epoch [139/200]
# Training Loss: 0.2106
# Validation Loss: 0.2114, Accuracy: 90.97%
# Epoch [140/200]
# Training Loss: 0.2245
# Validation Loss: 0.2080, Accuracy: 90.97%
# Epoch [141/200]
# Training Loss: 0.2234
# Validation Loss: 0.2088, Accuracy: 91.28%
# Epoch [142/200]
# Training Loss: 0.2225
# Validation Loss: 0.2090, Accuracy: 90.97%
# Epoch [143/200]
# Training Loss: 0.2130
# Validation Loss: 0.2281, Accuracy: 90.34%
# Epoch [144/200]
# Training Loss: 0.2052
# Validation Loss: 0.1970, Accuracy: 90.34%
# Epoch [145/200]
# Training Loss: 0.2108
# Validation Loss: 0.1910, Accuracy: 90.97%
# Epoch [146/200]
# Training Loss: 0.2039
# Validation Loss: 0.2015, Accuracy: 91.59%
# Epoch [147/200]
# Training Loss: 0.1783
# Validation Loss: 0.2168, Accuracy: 90.65%
# Epoch [148/200]
# Training Loss: 0.2603
# Validation Loss: 0.2376, Accuracy: 91.59%
# Epoch [149/200]
# Training Loss: 0.3168
# Validation Loss: 0.1818, Accuracy: 90.97%
# Epoch [150/200]
# Training Loss: 0.2322
# Validation Loss: 0.1943, Accuracy: 91.90%
# Epoch [151/200]
# Training Loss: 0.2488
# Validation Loss: 0.2064, Accuracy: 91.28%
# Epoch [152/200]
# Training Loss: 0.2709
# Validation Loss: 0.1848, Accuracy: 90.34%
# Epoch [153/200]
# Training Loss: 0.2182
# Validation Loss: 0.1869, Accuracy: 90.97%
# Epoch [154/200]
# Training Loss: 0.2244
# Validation Loss: 0.1912, Accuracy: 91.59%
# Epoch [155/200]
# Training Loss: 0.2570
# Validation Loss: 0.1898, Accuracy: 92.21%
# Epoch [156/200]
# Training Loss: 0.2059
# Validation Loss: 0.1993, Accuracy: 93.15%
# Epoch [157/200]
# Training Loss: 0.2193
# Validation Loss: 0.1977, Accuracy: 92.21%
# Epoch [158/200]
# Training Loss: 0.1957
# Validation Loss: 0.2064, Accuracy: 92.21%
# Epoch [159/200]
# Training Loss: 0.2094
# Validation Loss: 0.1977, Accuracy: 91.28%
# Epoch [160/200]
# Training Loss: 0.2226
# Validation Loss: 0.1830, Accuracy: 92.21%
# Epoch [161/200]
# Training Loss: 0.2338
# Validation Loss: 0.1988, Accuracy: 91.90%
# Epoch [162/200]
# Training Loss: 0.2549
# Validation Loss: 0.2176, Accuracy: 91.28%
# Epoch [163/200]
# Training Loss: 0.2695
# Validation Loss: 0.1932, Accuracy: 90.97%
# Epoch [164/200]
# Training Loss: 0.3154
# Validation Loss: 0.2076, Accuracy: 90.65%
# Epoch [165/200]
# Training Loss: 0.3822
# Validation Loss: 0.1964, Accuracy: 91.28%
# Epoch [166/200]
# Training Loss: 0.2707
# Validation Loss: 0.2189, Accuracy: 90.03%
# Epoch [167/200]
# Training Loss: 0.2182
# Validation Loss: 0.2338, Accuracy: 90.34%
# Epoch [168/200]
# Training Loss: 0.2224
# Validation Loss: 0.2118, Accuracy: 90.97%
# Epoch [169/200]
# Training Loss: 0.2238
# Validation Loss: 0.2069, Accuracy: 90.97%
# Epoch [170/200]
# Training Loss: 0.2024
# Validation Loss: 0.2096, Accuracy: 91.59%
# Epoch [171/200]
# Training Loss: 0.2862
# Validation Loss: 0.2309, Accuracy: 90.03%
# Epoch [172/200]
# Training Loss: 0.2491
# Validation Loss: 0.2129, Accuracy: 91.28%
# Epoch [173/200]
# Training Loss: 0.2034
# Validation Loss: 0.2256, Accuracy: 90.97%
# Epoch [174/200]
# Training Loss: 0.2252
# Validation Loss: 0.2033, Accuracy: 91.28%
# Epoch [175/200]
# Training Loss: 0.2260
# Validation Loss: 0.2130, Accuracy: 90.97%
# Epoch [176/200]
# Training Loss: 0.2343
# Validation Loss: 0.2016, Accuracy: 90.65%
# Epoch [177/200]
# Training Loss: 0.2085
# Validation Loss: 0.2036, Accuracy: 90.97%
# Epoch [178/200]
# Training Loss: 0.2007
# Validation Loss: 0.2074, Accuracy: 91.28%
# Epoch [179/200]
# Training Loss: 0.2266
# Validation Loss: 0.1880, Accuracy: 91.59%
# Epoch [180/200]
# Training Loss: 0.2230
# Validation Loss: 0.1913, Accuracy: 92.52%
# Epoch [181/200]
# Training Loss: 0.2210
# Validation Loss: 0.2015, Accuracy: 92.21%
# Epoch [182/200]
# Training Loss: 0.1851
# Validation Loss: 0.2197, Accuracy: 91.28%
# Epoch [183/200]
# Training Loss: 0.1875
# Validation Loss: 0.1874, Accuracy: 92.21%
# Epoch [184/200]
# Training Loss: 0.1908
# Validation Loss: 0.2092, Accuracy: 91.28%
# Epoch [185/200]
# Training Loss: 0.2044
# Validation Loss: 0.2080, Accuracy: 91.59%
# Epoch [186/200]
# Training Loss: 0.2038
# Validation Loss: 0.2032, Accuracy: 91.90%
# Epoch [187/200]
# Training Loss: 0.3032
# Validation Loss: 0.2667, Accuracy: 90.65%
# Epoch [188/200]
# Training Loss: 0.3486
# Validation Loss: 0.2086, Accuracy: 91.90%
# Epoch [189/200]
# Training Loss: 0.2416
# Validation Loss: 0.2008, Accuracy: 91.28%
# Epoch [190/200]
# Training Loss: 0.1877
# Validation Loss: 0.2207, Accuracy: 91.90%
# Epoch [191/200]
# Training Loss: 0.2259
# Validation Loss: 0.2046, Accuracy: 90.65%
# Epoch [192/200]
# Training Loss: 0.1999
# Validation Loss: 0.2235, Accuracy: 90.97%
# Epoch [193/200]
# Training Loss: 0.2006
# Validation Loss: 0.2300, Accuracy: 91.28%
# Epoch [194/200]
# Training Loss: 0.2012
# Validation Loss: 0.2154, Accuracy: 91.90%
# Epoch [195/200]
# Training Loss: 0.1927
# Validation Loss: 0.2085, Accuracy: 91.59%
# Epoch [196/200]
# Training Loss: 0.2060
# Validation Loss: 0.2066, Accuracy: 90.97%
# Epoch [197/200]
# Training Loss: 0.2007
# Validation Loss: 0.2471, Accuracy: 90.65%
# Epoch [198/200]
# Training Loss: 0.2375
# Validation Loss: 0.2224, Accuracy: 90.65%
# Epoch [199/200]
# Training Loss: 0.1969
# Validation Loss: 0.2332, Accuracy: 90.65%
# Epoch [200/200]
# Training Loss: 0.2099
# Validation Loss: 0.2134, Accuracy: 91.90%
# 0.17508094012737274

# %%
print("=> loading checkpoint")
best_model = torch.load('./Models/model_best.pth.tar')
print('best_prec1 = ', best_model['best_prec1'])
iceNet.load_state_dict(best_model['state_dict'])
optimizer.load_state_dict(best_model['optimizer'])
# Out:
# => loading checkpoint
# best_prec1 =  0.16314317286014557

# %%
temp_dataset = icebergDataset(X_train)

# %%
# Predict
iceNet.eval()
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=1, shuffle=False)
results = []
for features, features_angle in test_loader:
    iceNet.eval()
    features = Variable(features, volatile=True).cuda()
    features_angle = Variable(features_angle, volatile=True).cuda()
    outputs = F.softmax(iceNet(features, features_angle))
#     outputs = iceNet(features, features_angle)

    results.append(outputs.data[0][1])

# %%
sum(y_train>0.5)/len(y_train)
# Out:
# 0.45908028059236167

# %%
sum(np.array(results)>0.5)/len(results)
# Out:
# 0.30282526115859448

# %%
results[:50]
# Out:
# [0.02592930756509304,
#  0.3247637450695038,
#  1.0454600713242189e-14,
#  0.9999004602432251,
#  0.40994328260421753,
#  0.6011435389518738,
#  0.024099018424749374,
#  0.9999616146087646,
#  2.8529889561923483e-10,
#  2.0306337167319555e-10,
#  1.0756996557609658e-15,
#  0.30658578872680664,
#  1.2682083252002485e-05,
#  0.29034730792045593,
#  4.115712783914205e-07,
#  0.0020702641922980547,
#  0.0006665511173196137,
#  0.001083467504940927,
#  0.003712332108989358,
#  0.9074830412864685,
#  0.02027943916618824,
#  0.18286937475204468,
#  0.23720575869083405,
#  0.12182788550853729,
#  3.2119743469767245e-14,
#  7.707850357974166e-09,
#  0.007208712864667177,
#  0.4834314286708832,
#  0.1449306458234787,
#  0.9999291896820068,
#  1.087272768563255e-13,
#  0.6034151315689087,
#  0.4970799684524536,
#  0.016889972612261772,
#  0.7639496326446533,
#  0.9922479391098022,
#  0.0013621319085359573,
#  0.2865104377269745,
#  0.28295210003852844,
#  0.8613411784172058,
#  3.21758954014231e-15,
#  0.5548590421676636,
#  0.8960628509521484,
#  2.0677757675002795e-06,
#  0.6169924736022949,
#  0.9477837085723877,
#  0.9972792267799377,
#  8.354654241549858e-21,
#  0.9999982118606567,
#  0.6218925714492798]

# %%
sub = pd.read_csv('./Data/sample_submission.csv')

# %%
sub['is_iceberg'] = results

# %%
sub.to_csv('./Submissions/sub_30Oct_val_1631.csv', index=False)

# %% [markdown]
# #### KFold

# %%
def scale_test_range (input_, train_min, train_max, min_, max_):
    input_ += -(train_min)
    input_ /= train_max / (max_ - min_)
    input_ += min_
    return input_

def std_test_range (input_, mean, sd):
    input_ -= mean
    input_ /= sd
    return input_

# %%
def weight_init(m): 
    if isinstance(m, nn.Conv2d):
        torch.nn.init.xavier_uniform(m.weight.data)
    if isinstance(m, nn.Linear):
        torch.nn.init.orthogonal(m.weight.data)

# %%
band_1_KF = np.concatenate([im for im in data['band_1']]).reshape(-1, 75, 75)
band_2_KF = np.concatenate([im for im in data['band_2']]).reshape(-1, 75, 75)
# band_3_KF = scale_range(band_1_KF/band_2_KF, -1, 1)
X_KF = np.stack((band_1_KF, band_2_KF), axis=1)
X_KF = [X_KF, np.array(data['inc_angle']).reshape((len(data), 1))]

# X_test[0] = scale_test_range(X_test[0], train_min, train_max, -1, 1)
y_KF = data['is_iceberg'].values.astype(np.float32)

# %%
# band_1_KF = np.concatenate([im for im in data['band_1']]).reshape(-1, 75, 75)
# band_2_KF = np.concatenate([im for im in data['band_2']]).reshape(-1, 75, 75)
# band_3_KF = band_1_KF/band_2_KF

# band_1_test = np.concatenate([im for im in test['band_1']]).reshape(-1, 75, 75)
# band_2_test = np.concatenate([im for im in test['band_2']]).reshape(-1, 75, 75)
# band_3_test = band_1_test/band_2_test

# min_b1_KF, max_b1_KF = np.min(np.concatenate((band_1_KF, band_1_test), axis=0)), np.max(np.concatenate((band_1_KF, band_1_test), axis=0))
# min_b2_KF, max_b2_KF = np.min(np.concatenate((band_2_KF, band_2_test), axis=0)), np.max(np.concatenate((band_2_KF, band_2_test), axis=0))
# min_b3_KF, max_b3_KF = np.min(np.concatenate((band_3_KF, band_3_test), axis=0)), np.max(np.concatenate((band_3_KF, band_3_test), axis=0))

# band_1_KF = scale_test_range(band_1_KF, min_b1_KF, max_b1_KF, -1, 1)
# band_2_KF = scale_test_range(band_2_KF, min_b2_KF, max_b2_KF, -1, 1)
# band_1_test = scale_test_range(band_1_test, min_b1_KF, max_b1_KF, -1, 1)
# band_2_test = scale_test_range(band_2_test, min_b2_KF, max_b2_KF, -1, 1)
# band_3_KF = scale_test_range(band_3_KF, min_b3_KF, max_b3_KF, -1, 1)
# band_3_test = scale_test_range(band_3_test, min_b3_KF, max_b3_KF, -1, 1)
                          
# rgb = np.stack((band_1_KF, band_2_KF, band_3_KF), axis=1)
# X_KF = [rgb, np.array(data['inc_angle']).reshape((len(data), 1))]

# rgb = np.stack((band_1_test, band_2_test, band_3_test), axis=1)
# X_test = [rgb, np.array(test['inc_angle']).reshape((len(test), 1))]

# y_KF = data['is_iceberg'].values.astype(np.float32)

# %%
def accuracy(loader):
    iceNet.eval()
    correct = 0
    total = 0
    loss = []
    for features, features_angle, labels in loader:
        features = Variable(features, volatile=True).cuda()
        features_angle = Variable(features_angle, volatile=True).cuda()
        labels = Variable(labels, volatile=True).cuda()
        outputs = iceNet(features, features_angle)
        _loss = criterion(outputs, labels)
        loss.append(_loss)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.data).sum()
        
    return np.mean(loss).data[0], (100 * correct / total)

# %%
num_epochs = 300
batch_size = 32
learning_rate = 0.001

# %%
kfold = 5
kfold_scores = []

test_dataset = icebergDataset(X_test)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=1, shuffle=False)

results = []
sss = KFold(n_splits=kfold, random_state=0)
for i, (train_index, test_index) in enumerate(sss.split(X_KF[0], X_KF[1], y_KF)):
    X_train_KF, X_valid_KF = [X_KF[0][train_index], X_KF[1][train_index]], [X_KF[0][test_index], X_KF[1][test_index]]
    y_train_KF, y_valid_KF = y_KF[train_index], y_KF[test_index]
    
    # Define model
    iceNet = net().apply(weight_init).cuda()
    
    # Loss and Optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(iceNet.parameters(), lr=learning_rate, weight_decay=0.0001)
    
    # Data Loader
    train_dataset_KF = icebergDataset(X_train_KF, y_train_KF, transform=True)
    val_dataset_KF = icebergDataset(X_valid_KF, y_valid_KF)

    train_loader_KF = torch.utils.data.DataLoader(dataset=train_dataset_KF, batch_size=batch_size, shuffle=True)
    val_loader_KF = torch.utils.data.DataLoader(dataset=val_dataset_KF, batch_size=batch_size, shuffle=False)
    
    print('Fold [%d/%d]' % (i+1, kfold))
    # Train
    best_prec1 = 1
    for epoch in range(num_epochs):
        epoch_train_loss = []
        for idx, (features, features_angle, labels) in enumerate(train_loader_KF):
            iceNet.train()
            features = Variable(features).cuda()
            features_angle = Variable(features_angle).cuda()
            labels = Variable(labels).cuda()
            # Forward + Backward + Optimize
            optimizer.zero_grad()
            outputs = iceNet(features, features_angle)
            loss = criterion(outputs, labels)
            epoch_train_loss.append(loss)
            loss.backward()
            optimizer.step()

        prec1 = accuracy(val_loader_KF)[0]
        
        # Save best model
        is_best = prec1 < best_prec1
        best_prec1 = min(prec1, best_prec1)
        save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': iceNet.state_dict(),
            'best_prec1': best_prec1,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filename='./Models/v1Nov_v1/model_fold_'+str(i+1)+'.pth.tar')
        
    print('Val Score : %f' % (best_prec1))
    kfold_scores.append(best_prec1)
    # Load best model
    best_model = torch.load('./Models/v1Nov_v1/model_fold_'+str(i+1)+'.pth.tar')
    iceNet.load_state_dict(best_model['state_dict'])
    optimizer.load_state_dict(best_model['optimizer'])
    
    # Predict
    iceNet.eval()
    
    results_fold = []
    for features, features_angle in test_loader:
        iceNet.eval()
        features = Variable(features, volatile=True).cuda()
        features_angle = Variable(features_angle, volatile=True).cuda()
        outputs = F.softmax(iceNet(features, features_angle))
    #     outputs = iceNet(features, features_angle)

        results_fold.append(outputs.data[0][1])
    
    results.append(results_fold)
# Out:
# /home/arsh/anaconda3/envs/torch/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# Fold [1/5]
# Val Score : 0.161293
# Fold [2/5]
# Val Score : 0.150261
# Fold [3/5]
# Val Score : 0.191190
# Fold [4/5]
# Val Score : 0.120093
# Fold [5/5]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-c7df6e5dc697> in <module>()
#      30     for epoch in range(num_epochs):
#      31         epoch_train_loss = []
# ---> 32         for idx, (features, features_angle, labels) in enumerate(train_loader_KF):
#      33             iceNet.train()
#      34             features = Variable(features).cuda()
#
# /home/arsh/anaconda3/envs/torch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     177         if self.num_workers == 0:  # same-process loading
#     178             indices = next(self.sample_iter)  # may raise StopIteration
# --> 179             batch = self.collate_fn([self.dataset[i] for i in indices])
#     180             if self.pin_memory:
#     181                 batch = pin_memory_batch(batch)
#
# /home/arsh/anaconda3/envs/torch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     177         if self.num_workers == 0:  # same-process loading
#     178             indices = next(self.sample_iter)  # may raise StopIteration
# --> 179             batch = self.collate_fn([self.dataset[i] for i in indices])
#     180             if self.pin_memory:
#     181                 batch = pin_memory_batch(batch)
#
# <ipython-input-7-c6db223553ea> in __getitem__(self, idx)
#      22             im = randomErodeDilate(im, u=0.2)
#      23             im = randomZoomOut(im, u=0.5)
# ---> 24             im = randomNoisy(im, u=0.4)
#      25             im = randomShift(im, u=0.3)
#      26
#
# /home/arsh/Projects/Kaggle/Statoil_iceberg_classifier/utils_diff_ch.py in randomNoisy(im, u)
#      80         elif noise_typ =="speckle":
#      81             ch,row,col = im.shape
# ---> 82             gauss = np.random.randn(ch,row,col)/np.random.randint(3,6)
#      83             gauss = gauss.reshape(ch,row,col)
#      84             noisy = im + im * gauss
#
# KeyboardInterrupt:

# %%
np.array(kfold_scores).mean()
# Out:
# 0.15133977830410003

# %%
kfold = 5
kfold_scores = []

test_dataset = icebergDataset(X_test)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=1, shuffle=False)

results = []
sss = KFold(n_splits=kfold, random_state=0)
for i, (train_index, test_index) in enumerate(sss.split(X_KF[0], X_KF[1], y_KF)):
    X_train_KF, X_valid_KF = [X_KF[0][train_index], X_KF[1][train_index]], [X_KF[0][test_index], X_KF[1][test_index]]
    y_train_KF, y_valid_KF = y_KF[train_index], y_KF[test_index]
    
    # Define model
    iceNet = net().apply(weight_init).cuda()
    
    # Loss and Optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(iceNet.parameters(), lr=learning_rate, weight_decay=0.0001)
    
    # Data Loader
    train_dataset_KF = icebergDataset(X_train_KF, y_train_KF, transform=True)
    val_dataset_KF = icebergDataset(X_valid_KF, y_valid_KF)

    train_loader_KF = torch.utils.data.DataLoader(dataset=train_dataset_KF, batch_size=batch_size, shuffle=True)
    val_loader_KF = torch.utils.data.DataLoader(dataset=val_dataset_KF, batch_size=batch_size, shuffle=False)
    
    print('Fold [%d/%d]' % (i+1, kfold))
    # Train
    best_prec1 = 1
    for epoch in range(num_epochs):
        epoch_train_loss = []
        for idx, (features, features_angle, labels) in enumerate(train_loader_KF):
            iceNet.train()
            features = Variable(features).cuda()
            features_angle = Variable(features_angle).cuda()
            labels = Variable(labels).cuda()
            # Forward + Backward + Optimize
            optimizer.zero_grad()
            outputs = iceNet(features, features_angle)
            loss = criterion(outputs, labels)
            epoch_train_loss.append(loss)
            loss.backward()
            optimizer.step()

        prec1 = accuracy(val_loader_KF)[0]
        
        # Save best model
        is_best = prec1 < best_prec1
        best_prec1 = min(prec1, best_prec1)
        save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': iceNet.state_dict(),
            'best_prec1': best_prec1,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filename='./Models/v1Nov_v1/model_fold_'+str(i+1)+'.pth.tar')
        
    print('Val Score : %f' % (best_prec1))
    kfold_scores.append(best_prec1)
    # Load best model
    best_model = torch.load('./Models/v1Nov_v1/model_fold_'+str(i+1)+'.pth.tar')
    iceNet.load_state_dict(best_model['state_dict'])
    optimizer.load_state_dict(best_model['optimizer'])
    
    # Predict
    iceNet.eval()
    
    results_fold = []
    for features, features_angle in test_loader:
        iceNet.eval()
        features = Variable(features, volatile=True).cuda()
        features_angle = Variable(features_angle, volatile=True).cuda()
        outputs = F.softmax(iceNet(features, features_angle))
    #     outputs = iceNet(features, features_angle)

        results_fold.append(outputs.data[0][1])
    
    results.append(results_fold)
# Out:
# /home/arsh/anaconda3/envs/torch/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# Fold [1/5]
# Val Score : 0.139978
# Fold [2/5]
# Val Score : 0.147510
# Fold [3/5]
# Val Score : 0.188782
# Fold [4/5]
# Val Score : 0.123161
# Fold [5/5]
# Val Score : 0.098183

# %%
np.array(kfold_scores).mean()
# Out:
# 0.13952273428440093

# %%
np.array(sub['is_iceberg']<0.5).sum()
# Out:
# 8424

# %%
sub = pd.read_csv('./Data/sample_submission.csv')
sub['is_iceberg'] = np.array(results).mean(axis=0)
sub.to_csv('./Submissions/Sub 12 - 5-fold _ Val-1395.csv', index=False)

# %%
sub = pd.read_csv('./Data/sample_submission.csv')

# %%
sub1 = pd.read_csv('./Submissions/Sub 3 - 5 fold _ Val - 0.1504.csv')['is_iceberg']
sub2 = pd.read_csv('./Submissions/Sub 4 - 10-fold _ Val-1269.csv')['is_iceberg']
sub3 = pd.read_csv('./Submissions/Sub 5 - 5-fold _ Val-1538.csv')['is_iceberg']
sub4 = pd.read_csv('./Submissions/Sub 6 - 5-fold _ Val-1480.csv')['is_iceberg']
sub5 = pd.read_csv('./Submissions/Sub 8 - 5-fold _ Val-1479.csv')['is_iceberg']
sub6 = pd.read_csv('./Submissions/Sub 16 - 5-fold _ Val-1422.csv')['is_iceberg']

# %%
results = 1/np.mean((1/np.array(sub1), 1/np.array(sub3),
                   1/np.array(sub4), 1/np.array(sub2), 1/np.array(sub6), 1/np.array(sub5)), axis=0)
sub['is_iceberg'] = np.array(results)
sub.to_csv('./Submissions/Sub 18 - Ensemble_3_4_5_6_8_16 - Harmonic Mean.csv', index=False)

# %% [markdown]
# #### Error Analysis

# %%
def accuracy(loader):
    iceNet.eval()
    correct = 0
    total = 0
    loss = []
    inc_features = []
    inc_feature_angles = []
    inc_labels = []
    for features, features_angle, labels in loader:
        features = Variable(features, volatile=True).cuda()
        features_angle = Variable(features_angle, volatile=True).cuda()
        labels = Variable(labels, volatile=True).cuda()
        outputs = iceNet(features, features_angle)
        _loss = criterion(outputs, labels)
        loss.append(_loss)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.data).sum()
        inc_features.append(features.data.cpu().numpy()[np.where((predicted!=labels.data).cpu().numpy())])
        inc_feature_angles.append(features_angle.data.cpu().numpy()[np.where((predicted!=labels.data).cpu().numpy())])
        inc_labels.append(labels.data.cpu().numpy()[np.where((predicted!=labels.data).cpu().numpy())])
        
    return np.mean(loss).data[0], (100 * correct / total), [inc_features, inc_feature_angles, inc_labels]

# %%
kfold = 5
kfold_scores = []

results = []
sss = KFold(n_splits=kfold, random_state=0)
for i, (train_index, test_index) in enumerate(sss.split(X_KF[0], X_KF[1], y_KF)):
    if i == 2:
        X_train_KF, X_valid_KF = [X_KF[0][train_index], X_KF[1][train_index]], [X_KF[0][test_index], X_KF[1][test_index]]
        y_train_KF, y_valid_KF = y_KF[train_index], y_KF[test_index]

        # Define model
        iceNet = net().apply(weight_init).cuda()

        # Loss and Optimizer
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(iceNet.parameters(), lr=learning_rate, weight_decay=0.0001)

        # Data Loader
        train_dataset_KF = icebergDataset(X_train_KF, y_train_KF, transform=True)
        val_dataset_KF = icebergDataset(X_valid_KF, y_valid_KF)

        train_loader_KF = torch.utils.data.DataLoader(dataset=train_dataset_KF, batch_size=batch_size, shuffle=True)
        val_loader_KF = torch.utils.data.DataLoader(dataset=val_dataset_KF, batch_size=batch_size, shuffle=False)

        print('Fold [%d/%d]' % (i+1, kfold))
        # Train
        best_prec1 = 1
        for epoch in range(num_epochs):
            epoch_train_loss = []
            for idx, (features, features_angle, labels) in enumerate(train_loader_KF):
                iceNet.train()
                features = Variable(features).cuda()
                features_angle = Variable(features_angle).cuda()
                labels = Variable(labels).cuda()
                # Forward + Backward + Optimize
                optimizer.zero_grad()
                outputs = iceNet(features, features_angle)
                loss = criterion(outputs, labels)
                epoch_train_loss.append(loss)
                loss.backward()
                optimizer.step()
            
            acc = accuracy(val_loader_KF)
            prec1 = acc[0]

            # Save best model
            is_best = prec1 < best_prec1
            best_prec1 = min(prec1, best_prec1)
            if is_best:
                incorrect = acc[2]
print(best_prec1)
# Out:
# /home/arsh/anaconda3/envs/torch/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# Fold [3/5]
# 0.20910272002220154

# %%
incorrect[0] = np.vstack(incorrect[0])
incorrect[1] = np.vstack(incorrect[1])
incorrect[2] = np.hstack(incorrect[2])

# %%
for idx, im in enumerate(incorrect[0]):
    f, axarr = plt.subplots(1, 2)
    plt.title('Label = '+str(incorrect[2][idx])+', Inc Angle = '+str(incorrect[1][idx][0]))
    axarr[0].imshow(im[0], cmap='gray')
    axarr[1].imshow(im[1], cmap='gray')
    plt.show()
